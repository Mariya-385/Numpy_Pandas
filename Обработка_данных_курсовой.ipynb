# %%
import numpy as np
import pandas as pd

# %%
DATASET_PATH_TRAIN = 'train_prepared.csv'
DATASET_PATH_TEST = 'test_prepared.csv'

# %%
pd.read_csv(DATASET_PATH_TRAIN)
pd.read_csv(DATASET_PATH_TEST)
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0       725          58    2.0  49.882643   33.432782            6.0      6
# 1     15856          74    2.0  69.263183   32.781260            6.0      6
# 2      5480         190    1.0  13.597819   15.948246           12.0      2
# 3     15664          47    2.0  73.046609   51.940842            9.0     22
# 4     14275          27    1.0  47.527111   43.387569            6.0     17
# ...     ...         ...    ...        ...         ...            ...    ...
# 4995   8180          11    3.0  67.133911   50.809797            6.0      5
# 4996   4695           1    1.0  40.198472   21.807061           10.0     12
# 4997   5783          12    3.0  77.842178   48.282625            9.0     23
# 4998   4780          62    2.0  81.305222   32.781260            6.0      4
# 4999  12504          30    2.0  60.555693   32.781260            6.0     10
#
# ...

# %% [markdown]
# **Сохранение результатов**

# %%
PREPARED_DATASET_PATH_TRAIN = 'train_prepared.csv'
PREPARED_DATASET_PATH_TEST = 'test_prepared.csv'

# %%
df_test.to_csv(PREPARED_DATASET_PATH_TEST, index=False, encoding='utf-8')

# %%
df_train.to_csv(PREPARED_DATASET_PATH_TRAIN, index=False, encoding='utf-8')

# %% [markdown]
# **Подгружаем сохраненные датафреймы**

# %% [markdown]
# **На самом деле я не предполагала, что файл с обработкой должен быть отправлен, тк он слишком большой. Поэтому использовала его как мне удобно. На этом эатпе я уже более 500 раз вызывала обработанный датафрейм, из которого удалила уже давно поле ID. Поэтому здесь сразу подгружен фрейм уже на какой-то из стадий обработок**

# %%
df_train = pd.read_csv(DATASET_PATH_TRAIN)
df_train.head(20)
# Out:
#     DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0           35      2   47.981561   29.442751            6.0      7
# 1           41      3   65.683640   40.049543            8.0      7
# 2           53      2   44.947953   29.197612            6.0      8
# 3           58      2   53.352981   52.731512            9.0      8
# 4           99      1   39.649192   23.776169            7.0     11
# 5           59      3   80.384479   46.683720           12.0      5
# 6          154      2   62.254114   37.160377            7.0      3
# 7           74      2   80.312926   32.781260            6.0     14
# 8            1      2   64.511437   32.781260            6.0      9
# 9           23      1   46.461409   18.915552            8.0     13
# 10          28      2   46.304907   27.922584            6.0      8
# 11          31      3   68.808859   45.736906            7.0      1
# 12          13      2   54.522805   31.759753            6.0      8
# ...

# %%
df_test = pd.read_csv(DATASET_PATH_TEST)
df_test.head()
# Out:
#    DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0          58      2  49.882643   33.432782            6.0      6          14
# 1          74      2  69.263183   32.781260            6.0      7           1
# 2         190      1  13.597819    8.488472           12.0      2           5
# 3          47      2  73.046609   51.940842            9.0     22          22
# 4          27      1  47.527111   43.387569            6.0     17          17
#
#    HouseYear  Ecology_1  Social_1  ...  Social_3  Healthcare_1  Helthcare_2  \
# 0       1972   0.310199        11  ...         1           900            0
# 1       1977   0.075779         6  ...         3           900            0
# 2       1909   0.000000        30  ...         2           900            5
# 3       2007   0.101872        23  ...         3           900            3
# 4       2017   0.072158         2  ...         1           900            0
#
# ...

# %%
df_train.describe()
# Out:
#                 Id    DistrictId        Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  9989.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800     1.888678     55.609345     35.433983
# std     4859.01902     43.587592     0.812535     17.404470     13.467887
# min        0.00000      0.000000     1.000000     13.784865     10.523868
# 25%     4169.50000     20.000000     1.000000     41.794392     27.654813
# 50%     8394.50000     36.000000     2.000000     52.512820     32.781260
# 75%    12592.50000     75.000000     2.000000     65.614871     41.052147
# max    16798.00000    209.000000     6.000000    124.936036     99.970065
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        7.323900      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
df_test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  4997.000000  5000.000000  5000.000000
# mean    8412.595400    51.279200     1.907745    55.892261    35.554279
# std     4832.674037    44.179466     0.810321    17.355570    13.320468
# min        1.000000     0.000000     1.000000    13.305531    10.692499
# 25%     4221.750000    21.000000     1.000000    41.940806    27.990919
# 50%     8320.500000    37.000000     2.000000    52.512820    32.781260
# 75%    12598.250000    77.000000     2.000000    65.976417    41.247561
# max    16795.000000   212.000000     6.000000   124.285215    99.538614
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        7.287000     8.632000    12.601000  1984.392600     0.119874
# std         2.133153     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     10000 non-null  float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  float64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   10000 non-null  float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   int64
#  1   DistrictId     5000 non-null   int64
#  2   Rooms          5000 non-null   float64
#  3   Square         5000 non-null   float64
#  4   LifeSquare     5000 non-null   float64
#  5   KitchenSquare  5000 non-null   float64
#  6   Floor          5000 non-null   float64
#  7   HouseFloor     5000 non-null   float64
#  8   HouseYear      5000 non-null   int64
#  9   Ecology_1      5000 non-null   float64
#  10  Ecology_2      5000 non-null   object
#  11  Ecology_3      5000 non-null   object
#  12  Social_1       5000 non-null   int64
#  13  Social_2       5000 non-null   int64
#  14  Social_3       5000 non-null   int64
#  15  Healthcare_1   5000 non-null   float64
#  16  Helthcare_2    5000 non-null   int64
# ...

# %%
df_train['Id'] = df_train['Id'].astype(str)
df_train['Id'].dtype
# Out:
# dtype('O')

# %%
df_test['Id'] = df_test['Id'].astype(str)
df_test['Id'].dtype
# Out:
# dtype('O')

# %%
df_train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.888800     55.609345     34.311333
# std     4859.01902     43.587592      0.812096     17.404470     12.254976
# min        0.00000      0.000000      1.000000     13.784865      8.605237
# 25%     4169.50000     20.000000      1.000000     41.794392     25.915361
# 50%     8394.50000     36.000000      2.000000     52.512820     32.781260
# 75%    12592.50000     75.000000      2.000000     65.614871     38.784941
# max    16798.00000    209.000000      6.000000    124.936036     99.970065
#
#        KitchenSquare         Floor    HouseFloor    HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean        7.323900      7.903600     13.067200   1985.16570      0.118858
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.910000    56.449500    36.158810       5.976800
# std      44.179466     0.838594    19.092787    17.825287       9.950018
# min       0.000000     0.000000     1.378543     0.333490       0.000000
# 25%      21.000000     1.000000    41.906231    23.092026       1.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000    17.000000   223.453689   303.071094     620.000000
#
#              Floor   HouseFloor    HouseYear    Ecology_1     Social_1  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      8.632000    12.601000  1984.392600     0.119874    24.933800
# std       5.483228     6.789213    18.573149     0.120070    17.532202
# ...

# %% [markdown]
# **Смотрим данные типа object**

# %%
df_obj_features_train = df_train.select_dtypes(include='object')
df_obj_features_train.head()
# Out:
#       Id Ecology_2 Ecology_3 Shops_2
# 0  14038         B         B       B
# 1  15053         B         B       B
# 2   4765         B         B       B
# 3   5809         B         B       B
# 4  10783         B         B       B

# %%
df_obj_features_test = df_test.select_dtypes(include='object')
df_obj_features_test.head()
# Out:
#       Id Ecology_2 Ecology_3 Shops_2
# 0    725         B         B       B
# 1  15856         B         B       B
# 2   5480         B         B       B
# 3  15664         B         B       B
# 4  14275         B         B       A

# %% [markdown]
# **Смотрим, сколько каких значений в этих данных**

# %% [markdown]
# Тут я просто в этой строке перебирала каждый номинативный признак и поэтому не плодила много кода

# %%
df_test['Ecology_2'].value_counts()
# Out:
# B    4952
# A      48
# Name: Ecology_2, dtype: int64

# %% [markdown]
# Здесь я уже несколько раз проверяла данные после того, как заполняла пропуски. Поэтому теперь они без пробпусков

# %%
len(df_train) - df_train.count()
# Out:
# Id               0
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# Price            0
# dtype: int64

# %%
len(df_test) - df_test.count()
# Out:
# Id               0
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# dtype: int64

# %% [markdown]
# **Меняем LifeSquare на медиану на тесте**

# %%
df_test.loc[df_test['LifeSquare'].isnull(), 'LifeSquare'] = df_train['LifeSquare'].median()

# %% [markdown]
# **Повторяем на трейне**

# %%
df_train.loc[df_train['LifeSquare'].isnull(), 'LifeSquare'] = df_train['LifeSquare'].median()

# %% [markdown]
# **Меняем Healthcare_1 на медиану на тесте**

# %%
df_test.loc[df_test['Healthcare_1'].isnull(), 'Healthcare_1'] = df_train['Healthcare_1'].median()

# %% [markdown]
# **Повторяем на трейней**

# %%
df_train.loc[df_train['Healthcare_1'].isnull(), 'Healthcare_1'] = df_train['Healthcare_1'].median()

# %% [markdown]
# **Заполняем пустые Rooms**

# %%
df_train.loc[df_train['Rooms'].isnull(), 'Rooms'] = df_train['Rooms'].median()

# %%
df_train['Rooms'].isnull().value_counts()
# Out:
# False    10000
# Name: Rooms, dtype: int64

# %% [markdown]
# **Пустые Floor и HouseFloor**

# %%
df_train.loc[df_train['Floor'].isnull(), 'Floor'] = df_train['Floor'].median()

# %%
df_train.loc[df_train['HouseFloor'].isnull(), 'HouseFloor'] = 17

# %% [markdown]
# Тут стоит 17 потому что по каким-то причинам, когда я ставила = df_train... то значения оптом слетали. Я просто посмотрела, что это за значение, оно оказалось 17 и я заменила на 17.

# %%
df_train['Rooms'].mode()
# Out:
# 0    2.0
# dtype: float64

# %%
df_test.loc[df_test['HouseFloor'].isnull(), 'HouseFloor'] = 17

# %%
df_test.loc[df_test['Rooms'].isnull(), 'Rooms'] = 2

# %%
df_train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.888800     55.609345     34.311333
# std     4859.01902     43.587592      0.812096     17.404470     12.254976
# min        0.00000      0.000000      1.000000     13.784865      8.605237
# 25%     4169.50000     20.000000      1.000000     41.794392     25.915361
# 50%     8394.50000     36.000000      2.000000     52.512820     32.781260
# 75%    12592.50000     75.000000      2.000000     65.614871     38.784941
# max    16798.00000    209.000000      6.000000    124.936036     99.970065
#
#        KitchenSquare         Floor    HouseFloor    HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean        7.323900      7.903600     13.067200   1985.16570      0.118858
# ...

# %% [markdown]
# **Проверяем**

# %%
len(df_train) - df_train.count()
# Out:
# Id               0
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# Price            0
# dtype: int64

# %%
len(df_test) - df_test.count()
# Out:
# Id               0
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# dtype: int64

# %% [markdown]
# **Обработка выбросов на трейне**

# %% [markdown]
# В какой-то момент я поняла, что в табличном ивде - сложно сказать, что есть выбросы, а что нет. Построила диаграммы и уже смторя на них меняла, регулярно возвращаясь и просматривая диаграммы

# %%
df_train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.890500     56.315775     36.266040
# std     4859.01902     43.587592      0.839512     21.058732     76.609981
# min        0.00000      0.000000      0.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881     25.527399
# 50%     8394.50000     36.000000      2.000000     52.513310     32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625     41.427234
# max    16798.00000    209.000000     19.000000    641.065193   7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %% [markdown]
# **Rooms_train_max**

# %%
df_train[df_train['Rooms'] >6]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['Rooms'] > 6, 'Rooms'] = df_train['Rooms'].mode()

# %% [markdown]
# **Rooms_train_min**

# %%
df_train[df_train['Rooms'] ==0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397  12638          27    0.0  138.427694  136.215499            0.0      4
# 1981   7917          27    0.0  212.932361  211.231125            0.0      2
# 2269   7317          27    0.0   41.790881   32.781260            0.0     13
# 3911    770          28    0.0   49.483501   32.781260            0.0     16
# 4366    456           6    0.0   81.491446   32.781260            0.0      4
# 4853   3224          27    0.0    2.377248    0.873147            0.0      1
# 6149   3159          88    0.0   38.697117   19.345131            9.0      9
# 8834   9443          27    0.0   87.762616   85.125471            0.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397         3.0       2016   0.075424         B         B        11
# 1981         3.0       2008   0.211401         B         B         9
# ...

# %%
df_train.loc[df_train['Rooms'] ==0, 'Rooms'] = df_train['Rooms'].mode()

# %% [markdown]
# **Rooms_test_max**

# %%
df_test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  4997.000000  5000.000000  5000.000000
# mean    8412.595400    51.279200     1.907745    56.449500    35.455604
# std     4832.674037    44.179466     0.810321    19.092787    15.920269
# min        1.000000     0.000000     1.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    25.850152
# 50%     8320.500000    37.000000     2.000000    52.921340    32.781260
# 75%    12598.250000    77.000000     2.000000    66.285129    41.769526
# max    16795.000000   212.000000     6.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df_test[df_test['Rooms'] > 6]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df_test.loc[df_test['Rooms'] >6, 'Rooms'] = df_train['Rooms'].mode()

# %% [markdown]
# **Rooms_train_min**

# %%
df_test[df_test['Rooms'] == 0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2406   3343          58    0.0  116.824201  113.692424            0.0      3
# 2524  10729          27    0.0   76.345154   42.820796           12.0     14
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2406         3.0       1977   0.437885         B         B        23
# 2524         0.0       1977   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 2406      5735         3        1084.0            0        5       B
# 2524       469         0         900.0            0        0       B

# %%
df_test.loc[df_test['Rooms'] ==0, 'Rooms'] = df_train['Rooms'].mode()

# %% [markdown]
# **Square_train_max**

# %%
df_train.describe()
# Out:
#                 Id    DistrictId        Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  9989.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800     1.888678     56.201701     36.266040
# std     4859.01902     43.587592     0.812535     19.472731     76.609981
# min        0.00000      0.000000     1.000000      1.136859      0.370619
# 25%     4169.50000     20.000000     1.000000     41.774881     25.527399
# 50%     8394.50000     36.000000     2.000000     52.513040     32.781260
# 75%    12592.50000     75.000000     2.000000     65.890819     41.427234
# max    16798.00000    209.000000     6.000000    409.425181   7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
df_train[df_train['Square'] >125]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['Square'] >125, 'Square'] = df_train['Square'].median()

# %% [markdown]
# **Square_train_min**

# %%
df_train[df_train['Square'] <10]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['Square'] <10, 'Square'] = df_train['Square'].median()

# %%
df_train__num_features = df_train.select_dtypes(include='float64')

# %%
df_train__num_features.hist(figsize=(16,16), bins=20, grid=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021865E6B2C8>,
# ...
#       dtype=object)

# %% [markdown]
# **Square_test_max**

# %%
df_test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  4997.000000  5000.000000  5000.000000
# mean    8412.595400    51.279200     1.907745    56.381587    35.455604
# std     4832.674037    44.179466     0.810321    18.802428    15.920269
# min        1.000000     0.000000     1.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    25.850152
# 50%     8320.500000    37.000000     2.000000    52.901960    32.781260
# 75%    12598.250000    77.000000     2.000000    66.269760    41.769526
# max    16795.000000   212.000000     6.000000   189.679576   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df_test[df_test['Square'] >125]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df_test.loc[df_test['Square'] >125, 'Square'] = df_train['Square'].median()

# %%
df_test__num_features = df_test.select_dtypes(include='float64')

# %%
df_test__num_features.hist(figsize=(16,16), bins=20, grid=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000218684AA908>,
# ...
#       dtype=object)

# %% [markdown]
# **Square_test_min**

# %%
df_test.loc[df_test['Square'] <10, 'Square'] = df_train['Square'].median()

# %% [markdown]
# **LifeSquare_train_max**

# %%
df_train.describe()
# Out:
#                 Id    DistrictId        Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  9989.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800     1.888678     55.609345     35.433983
# std     4859.01902     43.587592     0.812535     17.404470     13.467887
# min        0.00000      0.000000     1.000000     13.784865     10.523868
# 25%     4169.50000     20.000000     1.000000     41.794392     27.654813
# 50%     8394.50000     36.000000     2.000000     52.512820     32.781260
# 75%    12592.50000     75.000000     2.000000     65.614871     41.052147
# max    16798.00000    209.000000     6.000000    124.936036     99.970065
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
df_train[df_train['LifeSquare'] >100]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['LifeSquare'] > 100, 'LifeSquare'] = df_train['LifeSquare'].median()

# %% [markdown]
# **LifeSquare_train_min**

# %%
df_train[df_train['LifeSquare'] <10]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['LifeSquare'] <10, 'LifeSquare'] = df_train['LifeSquare'].median()

# %% [markdown]
# **LifeSquare_test_max**

# %%
df_test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  4997.000000  5000.000000  5000.000000
# mean    8412.595400    51.279200     1.907745    55.892261    35.554279
# std     4832.674037    44.179466     0.810321    17.355570    13.320468
# min        1.000000     0.000000     1.000000    13.305531    10.692499
# 25%     4221.750000    21.000000     1.000000    41.940806    27.990919
# 50%     8320.500000    37.000000     2.000000    52.512820    32.781260
# 75%    12598.250000    77.000000     2.000000    65.976417    41.247561
# max    16795.000000   212.000000     6.000000   124.285215    99.538614
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df_test[df_test['LifeSquare'] >100]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df_test.loc[df_test['LifeSquare'] >100, 'LifeSquare'] = df_train['LifeSquare'].median()

# %% [markdown]
# **LifeSquare_test_min**

# %%
df_test[df_test['LifeSquare'] <10]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df_test.loc[df_test['LifeSquare'] <10, 'LifeSquare'] = df_train['LifeSquare'].median()

# %% [markdown]
# **KitchenSquare_train_max_min**

# %%
df_train.describe()
# Out:
#                 Id    DistrictId        Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  9989.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800     1.888678     55.609345     35.433983
# std     4859.01902     43.587592     0.812535     17.404470     13.467887
# min        0.00000      0.000000     1.000000     13.784865     10.523868
# 25%     4169.50000     20.000000     1.000000     41.794392     27.654813
# 50%     8394.50000     36.000000     2.000000     52.512820     32.781260
# 75%    12592.50000     75.000000     2.000000     65.614871     41.052147
# max    16798.00000    209.000000     6.000000    124.936036     99.970065
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        7.323900      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
df_train[df_train['KitchenSquare'] <1]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2      4765          53    2.0   44.947953   29.197612            0.0      8
# 7     11993          74    2.0   80.312926   32.781260            0.0     14
# 23     6641          54    3.0  118.907612   32.781260            0.0      2
# 26     4378          27    3.0  106.958871   32.781260            0.0     17
# 39     9371          23    2.0   60.503248   32.781260            0.0     16
# ...     ...         ...    ...         ...         ...            ...    ...
# 9948   8438           1    2.0   66.736039   32.781260            0.0     16
# 9953   5365           1    2.0   61.049491   32.781260            0.0     11
# 9960   9307           1    2.0   57.376642   32.781260            0.0      8
# 9965   6612          27    2.0   59.460685   32.781260            0.0     15
# 9987  15623          23    2.0   55.620092   32.781260            0.0      2
#
# ...

# %%
df_train.loc[df_train['KitchenSquare'] <1, 'KitchenSquare'] = df_train['KitchenSquare'].median()

# %%
df_train['KitchenSquare'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
df_train['KitchenSquare'].median()
# Out:
# 6.0

# %% [markdown]
# **KitchenSquare_test_max_min**

# %%
df_test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  4997.000000  5000.000000  5000.000000
# mean    8412.595400    51.279200     1.907745    55.892261    35.554279
# std     4832.674037    44.179466     0.810321    17.355570    13.320468
# min        1.000000     0.000000     1.000000    13.305531    10.692499
# 25%     4221.750000    21.000000     1.000000    41.940806    27.990919
# 50%     8320.500000    37.000000     2.000000    52.512820    32.781260
# 75%    12598.250000    77.000000     2.000000    65.976417    41.247561
# max    16795.000000   212.000000     6.000000   124.285215    99.538614
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df_test[df_test['KitchenSquare'] <1]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 22    12694          27    3.0  83.670032   46.358356            0.0      8
# 24     8968          27    2.0  69.849239   32.781260            0.0      3
# 30     2982           6    2.0  63.460684   32.781260            0.0     13
# 32     2449           1    1.0  66.426585   32.781260            0.0     14
# 43    11513           1    1.0  37.484057   40.593036            0.0      4
# ...     ...         ...    ...        ...         ...            ...    ...
# 4969   4821          74    2.0  82.542507   82.585069            0.0      4
# 4973   1804          27    1.0  38.916778   32.781260            0.0     11
# 4974   5296          52    1.0  44.442218   44.634608            0.0      5
# 4976   4723          95    1.0  45.542940   32.781260            0.0      6
# 4998   4780          62    2.0  81.305222   32.781260            0.0      4
#
# ...

# %%
df_test.loc[df_test['KitchenSquare'] <1, 'KitchenSquare'] = df_train['KitchenSquare'].median()

# %%
df_test['KitchenSquare'].mode()
# Out:
# 0    1.0
# dtype: float64

# %% [markdown]
# **HouseFloor_train**

# %%
df_train['HouseFloor'] = df_train['HouseFloor'].astype(int)
df_train['HouseFloor'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# **HouseFloor_test**

# %%
df_test['HouseFloor'] = df_test['HouseFloor'].astype(int)
df_test['HouseFloor'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# **Healthcare_1_train_max**

# %%
df_train.describe()
# Out:
#                 Id    DistrictId        Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  9989.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800     1.888678     55.609345     35.433983
# std     4859.01902     43.587592     0.812535     17.404470     13.467887
# min        0.00000      0.000000     1.000000     13.784865     10.523868
# 25%     4169.50000     20.000000     1.000000     41.794392     27.654813
# 50%     8394.50000     36.000000     2.000000     52.512820     32.781260
# 75%    12592.50000     75.000000     2.000000     65.614871     41.052147
# max    16798.00000    209.000000     6.000000    124.936036     99.970065
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        7.323900      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
df_train[df_train['Healthcare_1'] >3000]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['Healthcare_1'] >3000, 'Healthcare_1'] = df_train['Healthcare_1'].median()

# %% [markdown]
# **Healthcare_1_test_max**

# %%
df_test[df_test['Healthcare_1'] >3000]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 2      5480         190    1.0  13.597819   15.948246           12.0      2
# 49     6343          53    1.0  35.772276   20.554842            6.0      6
# 108   10290          84    1.0  37.336754   24.573349            9.0     11
# 119   16089          66    2.0  57.065173   36.959476            7.0      2
# 166    5317         111    1.0  38.828270   23.493251            7.0     16
# ...     ...         ...    ...        ...         ...            ...    ...
# 4864   2025         111    1.0  43.478698   23.315555            8.0      6
# 4896   9308          53    1.0  35.516639   22.000906            6.0      5
# 4930  16264          53    2.0  49.591881   32.607139            5.0      9
# 4933   8740         155    2.0  58.844373   31.653431            7.0      2
# 4976   4723          95    1.0  45.542940   32.781260            6.0      6
#
# ...

# %%
df_test.loc[df_test['Healthcare_1'] >3000, 'Healthcare_1'] = df_train['Healthcare_1'].median()

# %% [markdown]
# ****Соотношение признаков****

# %% [markdown]
# **Жилая больше общей_train**

# %%
df_train.describe()
# Out:
#                 Id    DistrictId        Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  9989.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800     1.888678     55.609345     35.433983
# std     4859.01902     43.587592     0.812535     17.404470     13.467887
# min        0.00000      0.000000     1.000000     13.784865     10.523868
# 25%     4169.50000     20.000000     1.000000     41.794392     27.654813
# 50%     8394.50000     36.000000     2.000000     52.512820     32.781260
# 75%    12592.50000     75.000000     2.000000     65.614871     41.052147
# max    16798.00000    209.000000     6.000000    124.936036     99.970065
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        7.323900      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
df_train[(df_train['LifeSquare'] > df_train['Square'])]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %% [markdown]
# Здесь, чтобы адекватно заменить, я посмотрела во сколько раз в среднем медиана жилой площади меньше, чем общей площади. Нашла это значение и там где жилая превосходила общую, я общую площадь умножала на полученное значение.

# %%
a = df_train['LifeSquare'].median()/df_train['Square'].median()
a
# Out:
# 0.6242525188423295

# %%
df_train.loc[(df_train['LifeSquare'] > df_train['Square']), 'LifeSquare'] = df_train['Square']*a

# %%
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0     14038          35    2.0  47.981561   29.442751            6.0      7
# 1     15053          41    3.0  65.683640   40.049543            8.0      7
# 2      4765          53    2.0  44.947953   29.197612            6.0      8
# 3      5809          58    2.0  53.352981   52.731512            9.0      8
# 5     12915          59    3.0  80.384479   46.683720           12.0      5
# ...     ...         ...    ...        ...         ...            ...    ...
# 9993     48          13    3.0  80.631333   48.899083           10.0     11
# 9994   4158          23    2.0  64.864198   32.781260            6.0     17
# 9995     77          32    2.0  50.401785   30.476203            5.0      6
# 9997   5123          27    1.0  47.939008   32.781260            6.0     12
# 9998   5400          75    2.0  43.602562   33.840147            8.0      1
#
# ...

# %% [markdown]
# **Жилая большей общей_test**

# %%
df_test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  4997.000000  5000.000000  5000.000000
# mean    8412.595400    51.279200     1.907745    55.892261    35.554279
# std     4832.674037    44.179466     0.810321    17.355570    13.320468
# min        1.000000     0.000000     1.000000    13.305531    10.692499
# 25%     4221.750000    21.000000     1.000000    41.940806    27.990919
# 50%     8320.500000    37.000000     2.000000    52.512820    32.781260
# 75%    12598.250000    77.000000     2.000000    65.976417    41.247561
# max    16795.000000   212.000000     6.000000   124.285215    99.538614
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        7.287000     8.632000    12.601000  1984.392600     0.119874
# std         2.133153     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df_test[(df_test['LifeSquare'] > df_test['Square'])]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df_test.loc[(df_test['LifeSquare'] > df_test['Square']), 'LifeSquare'] = df_test['Square']*b

# %% [markdown]
# **Этаж больше чем этажей в доме_train**

# %%
df_train[df_train['HouseFloor'] ==0]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['HouseFloor'] ==0, 'HouseFloor'] = df_train['HouseFloor'].mode()

# %%
df_train[(df_train['Floor'] > df_train['HouseFloor'])]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[(df_train['Floor'] > df_train['HouseFloor']), 'Floor'] = df_train['Floor'].mode()

# %% [markdown]
# **Этаж больше чем этажей в доме_test**

# %%
df_test[df_test['HouseFloor'] ==0]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df_test.loc[df_test['HouseFloor'] ==0, 'HouseFloor'] = df_train['HouseFloor'].mode()

# %%
df_test[(df_test['Floor'] > df_test['HouseFloor'])]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df_test.loc[(df_test['Floor'] > df_test['HouseFloor']), 'Floor'] = df_train['Floor'].mode()

# %% [markdown]
# **Проверка value_counts по всем столбцам**

# %% [markdown]
# Тут тоже, чтобы не плодить 21 строку, я просто меняла названия столбцов в строке кода и все.

# %%
df_test['HouseFloor'].value_counts()
# Out:
# 17.0    1282
# 9.0      724
# 5.0      550
# 12.0     526
# 14.0     344
# 16.0     235
# 1.0      230
# 22.0     193
# 25.0     179
# 24.0      98
# 8.0       72
# 3.0       69
# 10.0      64
# 4.0       58
# 19.0      51
# 15.0      49
# 20.0      48
# 18.0      44
# 6.0       35
# 7.0       28
# 2.0       26
# 23.0      22
# 13.0      13
# 11.0      11
# 40.0       9
# 21.0       9
# 30.0       5
# 27.0       5
# 26.0       4
# 48.0       3
# 28.0       2
# 37.0       2
# 32.0       2
# 39.0       2
# 99.0       1
# 33.0       1
# 29.0       1
# 36.0       1
# 34.0       1
# 31.0       1
# Name: HouseFloor, dtype: int64

# %%
df_train[df_train['HouseYear'] ==20052011]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['HouseYear'] ==20052011, 'HouseYear'] = 2005

# %%
df_train[df_train['HouseFloor'] ==2005]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['HouseFloor'] ==2005, 'HouseFloor'] = df_train['HouseFloor'].mode()

# %% [markdown]
# **Меняем тип Socail_2 на float**

# %%
df_train['Social_2'] = df_train['Social_2'].astype(float)

# %%
df_test['Social_2'] = df_test['Social_2'].astype(float)

# %% [markdown]
# **Social_2_train_max**

# %%
df_train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.888800     55.609345     34.311333
# std     4859.01902     43.587592      0.812096     17.404470     12.254976
# min        0.00000      0.000000      1.000000     13.784865      8.605237
# 25%     4169.50000     20.000000      1.000000     41.794392     25.915361
# 50%     8394.50000     36.000000      2.000000     52.512820     32.781260
# 75%    12592.50000     75.000000      2.000000     65.614871     38.784941
# max    16798.00000    209.000000      6.000000    124.936036     99.970065
#
#        KitchenSquare         Floor    HouseFloor    HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean        7.323900      7.903600     13.067200   1985.16570      0.118858
# ...

# %%
df_train[df_train['Social_2'] >12500]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
df_train.loc[df_train['Social_2'] > 12500, 'Social_2'] = df_train['Social_2'].median()

# %% [markdown]
# **Social_2_test_max**

# %%
df_test[df_test['Social_2'] >12500]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df_test.loc[df_test['Social_2'] > 12500, 'Social_2'] = df_train['Social_2'].median()

# %% [markdown]
# **Меняем тип у Floor and Hosefloor**

# %%
df_train['Floor'] = df_train['Floor'].astype(float)

# %%
df_test['Floor'] = df_test['Floor'].astype(float)

# %%
df_train['HouseFloor'] = df_train['HouseFloor'].astype(float)

# %%
df_test['HouseFloor'] = df_test['HouseFloor'].astype(float)

# %% [markdown]
# **Разбираемся с годом постройки дома**

# %%
df_train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.888800     55.609345     34.311333
# std     4859.01902     43.587592      0.812096     17.404470     12.254976
# min        0.00000      0.000000      1.000000     13.784865      8.605237
# 25%     4169.50000     20.000000      1.000000     41.794392     25.915361
# 50%     8394.50000     36.000000      2.000000     52.512820     32.781260
# 75%    12592.50000     75.000000      2.000000     65.614871     38.784941
# max    16798.00000    209.000000      6.000000    124.936036     99.970065
#
#        KitchenSquare         Floor    HouseFloor    HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  9999.000000  10000.000000
# mean        7.323900      7.903600     13.067200  1984.867387      0.118858
# ...

# %%
df_train['HouseYear'].mode()
# Out:
# 0    1977
# dtype: int64

# %%
df_train.loc[df_train['HouseYear'] ==4968, 'HouseYear'] = df_train['HouseYear'].mode()

# %%
df_test.describe()
# Out:
#                  Id   DistrictId       Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.00000  5000.000000  5000.000000
# mean    8412.595400    51.279200     1.90780    55.892261    34.232640
# std     4832.674037    44.179466     0.81008    17.355570    12.039345
# min        1.000000     0.000000     1.00000    13.305531     8.306012
# 25%     4221.750000    21.000000     1.00000    41.940806    26.087522
# 50%     8320.500000    37.000000     2.00000    52.512820    32.781260
# 75%    12598.250000    77.000000     2.00000    65.976417    38.398229
# max    16795.000000   212.000000     6.00000   124.285215    99.538614
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        7.287000     7.977400    13.046400  1984.392600     0.119874
# std         2.133153     4.743774     6.499315    18.573149     0.120070
# ...

# %% [markdown]
# **Social_3_train**

# %%
df_train[df_train['Social_3'] >15]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 20     8862           0    3.0  103.605292   47.799426           10.0   12.0
# 121   10935         121    3.0   60.438169   43.967851            5.0    5.0
# 133   15386         127    2.0   45.923673   26.177753            5.0    3.0
# 272    3309         127    1.0   36.528009   19.645381            9.0   12.0
# 290   13049          81    3.0   71.045992   52.836433            7.0    3.0
# ...     ...         ...    ...         ...         ...            ...    ...
# 9675  11221         121    3.0   69.364446   43.777691            7.0   11.0
# 9840   2484           0    3.0   70.322746   45.465960           10.0    8.0
# 9876   1975           0    1.0   34.890672   18.788704            6.0    6.0
# 9900  10797         121    3.0   51.650125   36.609585            5.0    2.0
# 9959  10361           0    1.0   32.416925   19.257869            6.0    7.0
#
# ...

# %%
df_train.loc[df_train['Social_3'] >12, 'Social_3'] = df_train['Social_3'].median()

# %% [markdown]
# **меняем тип на флоат, чтобы посмотреть на графике**

# %%
df_train['Social_3'] = df_train['Social_3'].astype(float)

# %% [markdown]
# **Social_3_test**

# %%
df_test['Social_3'] = df_test['Social_3'].astype(float)

# %%
df_test.loc[df_test['Social_3'] >12, 'Social_3'] = df_train['Social_3'].median()

# %% [markdown]
# **Смотрим на Shops**

# %%
df_train['Shops_1'] = df_train['Shops_1'].astype(float)

# %%
df_train.loc[df_train['Shops_1'] >12, 'Shops_1'] = df_train['Shops_1'].median()

# %%
df_test['Shops_1'] = df_test['Shops_1'].astype(float)

# %%
df_test.loc[df_test['Shops_1'] >12, 'Shops_1'] = df_train['Shops_1'].median()

# %% [markdown]
# # Проверяем соответствие типов данных и самих данных

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DistrictId     10000 non-null  int64
#  1   Rooms          10000 non-null  int64
#  2   Square         10000 non-null  float64
#  3   LifeSquare     10000 non-null  float64
#  4   KitchenSquare  10000 non-null  float64
#  5   Floor          10000 non-null  int64
#  6   HouseFloor     10000 non-null  int64
#  7   HouseYear      10000 non-null  int64
#  8   Ecology_1      10000 non-null  float64
#  9   Ecology_2      10000 non-null  object
#  10  Ecology_3      10000 non-null  object
#  11  Social_1       10000 non-null  int64
#  12  Social_2       10000 non-null  int64
#  13  Social_3       10000 non-null  int64
#  14  Healthcare_1   10000 non-null  int64
#  15  Helthcare_2    10000 non-null  int64
#  16  Shops_1        10000 non-null  int64
# ...

# %%
df_train['Rooms'] = df_train['Rooms'].astype(float)

# %%
df_train['Floor'] = df_train['Floor'].astype(float)

# %%
df_train['HouseYear'] = df_train['HouseYear'].astype(float)

# %%
df_train.loc[df_train['HouseYear'].isnull(), 'HouseYear'] = df_train['HouseYear'].median()

# %%
df_train['Social_2'] = df_train['Social_2'].astype(float)

# %%
df_train['Healthcare_1'] = df_train['Healthcare_1'].astype(float)

# %% [markdown]
# **Повторяем на тесте**

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   int64
#  1   DistrictId     5000 non-null   int64
#  2   Rooms          5000 non-null   int32
#  3   Square         5000 non-null   float64
#  4   LifeSquare     5000 non-null   float64
#  5   KitchenSquare  5000 non-null   float64
#  6   Floor          5000 non-null   int32
#  7   HouseFloor     5000 non-null   int32
#  8   HouseYear      5000 non-null   int32
#  9   Ecology_1      5000 non-null   float64
#  10  Ecology_2      5000 non-null   object
#  11  Ecology_3      5000 non-null   object
#  12  Social_1       5000 non-null   int64
#  13  Social_2       5000 non-null   int32
#  14  Social_3       5000 non-null   int32
#  15  Healthcare_1   5000 non-null   int32
#  16  Helthcare_2    5000 non-null   int64
# ...

# %%
df_test['Rooms'] = df_test['Rooms'].astype(float)

# %%
df_test['HouseYear'] = df_test['HouseYear'].astype(float)

# %%
df_test['Social_2'] = df_test['Social_2'].astype(float)

# %%
df_test['Healthcare_1'] = df_test['Healthcare_1'].astype(float)

# %% [markdown]
# **Мне почему-то показалось, что если я хочу, чтобы все эти призанки модель оценивала по-номральному, то они должны все иметь один и тот же тип данных - float. Поэтмоу я все заменила на него, даже если это на текущем этапе не видно ))**

# %% [markdown]
# # Отбор и построение новых признаков

# %% [markdown]
# ### Убираем ID

# %%
df_train = df_train.drop(['Id'], axis=1)

# %%
df_train.describe()
# Out:
#          DistrictId         Rooms        Square    LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean      50.400800      1.888800     55.609345     34.311333       7.323900
# std       43.587592      0.812096     17.404470     12.254976       2.169115
# min        0.000000      1.000000     13.784865      8.605237       2.000000
# 25%       20.000000      1.000000     41.794392     25.915361       6.000000
# 50%       36.000000      2.000000     52.512820     32.781260       6.000000
# 75%       75.000000      2.000000     65.614871     38.784941       9.000000
# max      209.000000      6.000000    124.936036     99.970065      20.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       7.903600     13.067200   1984.866600      0.118858     24.687000
# ...

# %%
df_test = df_test.drop(['Id'], axis=1)

# %%
df_test.describe()
# Out:
#         DistrictId       Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.00000  5000.000000  5000.000000    5000.000000
# mean     51.279200     1.90780    55.892261    34.232640       7.287000
# std      44.179466     0.81008    17.355570    12.039345       2.133153
# min       0.000000     1.00000    13.305531     8.306012       2.000000
# 25%      21.000000     1.00000    41.940806    26.087522       6.000000
# 50%      37.000000     2.00000    52.512820    32.781260       6.000000
# 75%      77.000000     2.00000    65.976417    38.398229       9.000000
# max     212.000000     6.00000   124.285215    99.538614      20.000000
#
#              Floor   HouseFloor    HouseYear    Ecology_1     Social_1  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      7.977400    13.046400  1984.392600     0.119874    24.933800
# std       4.743774     6.499315    18.573149     0.120070    17.532202
# ...

# %% [markdown]
# # Делаем дамми переменные

# %%
df_train = pd.concat([df_train, pd.get_dummies(df_train['Ecology_2'])], axis=1)
df_train.head()
# Out:
#    DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0          35      2  47.981561   29.442751            6.0      7           9
# 1          41      3  65.683640   40.049543            8.0      7           9
# 2          53      2  44.947953   29.197612            6.0      8          12
# 3          58      2  53.352981   52.731512            9.0      8          17
# 4          99      1  39.649192   23.776169            7.0     11          12
#
#    HouseYear  Ecology_1 Ecology_2  ... Social_1  Social_2  Social_3  \
# 0       1969   0.089040         B  ...       33      7976         5
# 1       1978   0.000070         B  ...       46     10309         1
# 2       1968   0.049637         B  ...       34      7759         0
# 3       1977   0.437885         B  ...       23      5735         3
# 4       1976   0.012339         B  ...       35      5776         1
#
#    Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price  A  B
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DistrictId     10000 non-null  int64
#  1   Rooms          10000 non-null  int64
#  2   Square         10000 non-null  float64
#  3   LifeSquare     10000 non-null  float64
#  4   KitchenSquare  10000 non-null  float64
#  5   Floor          10000 non-null  int64
#  6   HouseFloor     10000 non-null  int64
#  7   HouseYear      10000 non-null  int64
#  8   Ecology_1      10000 non-null  float64
#  9   Ecology_2      10000 non-null  object
#  10  Ecology_3      10000 non-null  object
#  11  Social_1       10000 non-null  int64
#  12  Social_2       10000 non-null  int64
#  13  Social_3       10000 non-null  int64
#  14  Healthcare_1   10000 non-null  int64
#  15  Helthcare_2    10000 non-null  int64
#  16  Shops_1        10000 non-null  int64
# ...

# %%
df_train.rename(columns={'A': 'Ecology_2_A', 'B': 'Ecology_2_B'}, inplace = True)

# %% [markdown]
# Тут выяснилось, что вместо Ecology_2_A и Ecology_2_B он мне поставил просто А и В. Пришлось переименовывать.

# %%
Ecology_3

# %%
df_train = pd.concat([df_train, pd.get_dummies(df_train['Ecology_3'])], axis=1)
df_train.head()
# Out:
#    DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0          35      2  47.981561   29.442751            6.0      7           9
# 1          41      3  65.683640   40.049543            8.0      7           9
# 2          53      2  44.947953   29.197612            6.0      8          12
# 3          58      2  53.352981   52.731512            9.0      8          17
# 4          99      1  39.649192   23.776169            7.0     11          12
#
#    HouseYear  Ecology_1 Ecology_2  ... Social_3  Healthcare_1  Helthcare_2  \
# 0       1969   0.089040         B  ...        5           900            0
# 1       1978   0.000070         B  ...        1           240            1
# 2       1968   0.049637         B  ...        0           229            1
# 3       1977   0.437885         B  ...        3          1084            0
# 4       1976   0.012339         B  ...        1          2078            2
#
# ...

# %%
df_train.rename(columns={'A': 'Ecology_3_A', 'B': 'Ecology_3_B'}, inplace = True)

# %%
df_train = pd.concat([df_train, pd.get_dummies(df_train['Shops_2'])], axis=1)
df_train.head()
# Out:
#    DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0          35      2  47.981561   29.442751            6.0      7           9
# 1          41      3  65.683640   40.049543            8.0      7           9
# 2          53      2  44.947953   29.197612            6.0      8          12
# 3          58      2  53.352981   52.731512            9.0      8          17
# 4          99      1  39.649192   23.776169            7.0     11          12
#
#    HouseYear  Ecology_1 Ecology_2  ... Helthcare_2  Shops_1  Shops_2  \
# 0       1969   0.089040         B  ...           0       11        B
# 1       1978   0.000070         B  ...           1        3        B
# 2       1968   0.049637         B  ...           1        3        B
# 3       1977   0.437885         B  ...           0        5        B
# 4       1976   0.012339         B  ...           2        4        B
#
#            Price  Ecology_2_A  Ecology_2_B  Ecology_3_A Ecology_3_B  A  B
# ...

# %%
df_train.rename(columns={'A': 'Shops_2_A', 'B': 'Shops_2_B'}, inplace = True)

# %% [markdown]
# **Повторяем на тесте**

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DistrictId     5000 non-null   int64
#  1   Rooms          5000 non-null   int64
#  2   Square         5000 non-null   float64
#  3   LifeSquare     5000 non-null   float64
#  4   KitchenSquare  5000 non-null   float64
#  5   Floor          5000 non-null   int64
#  6   HouseFloor     5000 non-null   int64
#  7   HouseYear      5000 non-null   int64
#  8   Ecology_1      5000 non-null   float64
#  9   Ecology_2      5000 non-null   object
#  10  Ecology_3      5000 non-null   object
#  11  Social_1       5000 non-null   int64
#  12  Social_2       5000 non-null   int64
#  13  Social_3       5000 non-null   int64
#  14  Healthcare_1   5000 non-null   int64
#  15  Helthcare_2    5000 non-null   int64
#  16  Shops_1        5000 non-null   int64
# ...

# %%
df_test = pd.concat([df_test, pd.get_dummies(df_test['Ecology_2'])], axis=1)
df_test.head()
# Out:
#    DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0          58      2  49.882643   33.432782            6.0      6          14
# 1          74      2  69.263183   32.781260            6.0      7           1
# 2         190      1  13.597819    8.488472           12.0      2           5
# 3          47      2  73.046609   51.940842            9.0     22          22
# 4          27      1  47.527111   43.387569            6.0     17          17
#
#    HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# 0       1972   0.310199         B         B        11      2748         1
# 1       1977   0.075779         B         B         6      1437         3
# 2       1909   0.000000         B         B        30      7538         2
# 3       2007   0.101872         B         B        23      4583         3
# 4       2017   0.072158         B         B         2       629         1
#
#    Healthcare_1  Helthcare_2  Shops_1 Shops_2  A  B
# ...

# %%
df_test.rename(columns={'A': 'Ecology_2_A', 'B': 'Ecology_2_B'}, inplace = True)

# %%
df_test = pd.concat([df_test, pd.get_dummies(df_test['Ecology_3'])], axis=1)
df_test.head()
# Out:
#    DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0          58      2  49.882643   33.432782            6.0      6          14
# 1          74      2  69.263183   32.781260            6.0      7           1
# 2         190      1  13.597819    8.488472           12.0      2           5
# 3          47      2  73.046609   51.940842            9.0     22          22
# 4          27      1  47.527111   43.387569            6.0     17          17
#
#    HouseYear  Ecology_1 Ecology_2  ... Social_2  Social_3  Healthcare_1  \
# 0       1972   0.310199         B  ...     2748         1           900
# 1       1977   0.075779         B  ...     1437         3           900
# 2       1909   0.000000         B  ...     7538         2           900
# 3       2007   0.101872         B  ...     4583         3           900
# 4       2017   0.072158         B  ...      629         1           900
#
#    Helthcare_2  Shops_1  Shops_2  Ecology_2_A Ecology_2_B  A  B
# ...

# %%
df_test.rename(columns={'A': 'Ecology_3_A', 'B': 'Ecology_3_B'}, inplace = True)

# %%
df_test = pd.concat([df_test, pd.get_dummies(df_test['Shops_2'])], axis=1)
df_test.head()
# Out:
#    DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0          58      2  49.882643   33.432782            6.0      6          14
# 1          74      2  69.263183   32.781260            6.0      7           1
# 2         190      1  13.597819    8.488472           12.0      2           5
# 3          47      2  73.046609   51.940842            9.0     22          22
# 4          27      1  47.527111   43.387569            6.0     17          17
#
#    HouseYear  Ecology_1 Ecology_2  ... Healthcare_1  Helthcare_2  Shops_1  \
# 0       1972   0.310199         B  ...          900            0        0
# 1       1977   0.075779         B  ...          900            0        2
# 2       1909   0.000000         B  ...          900            5        5
# 3       2007   0.101872         B  ...          900            3        3
# 4       2017   0.072158         B  ...          900            0        0
#
# ...

# %%
df_test.rename(columns={'A': 'Shops_2_A', 'B': 'Shops_2_B'}, inplace = True)

# %% [markdown]
# ## Удаляем столбцы object

# %%
df_train = df_train.drop(['Ecology_2', 'Ecology_3', 'Shops_2'], axis=1)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DistrictId     10000 non-null  int64
#  1   Rooms          10000 non-null  int64
#  2   Square         10000 non-null  float64
#  3   LifeSquare     10000 non-null  float64
#  4   KitchenSquare  10000 non-null  float64
#  5   Floor          10000 non-null  int64
#  6   HouseFloor     10000 non-null  int64
#  7   HouseYear      10000 non-null  int64
#  8   Ecology_1      10000 non-null  float64
#  9   Social_1       10000 non-null  int64
#  10  Social_2       10000 non-null  int64
#  11  Social_3       10000 non-null  int64
#  12  Healthcare_1   10000 non-null  int64
#  13  Helthcare_2    10000 non-null  int64
#  14  Shops_1        10000 non-null  int64
#  15  Price          10000 non-null  float64
#  16  Ecology_2_A    10000 non-null  int64
# ...

# %%
df_test = df_test.drop(['Ecology_2', 'Ecology_3', 'Shops_2'], axis=1)

# %% [markdown]
# # Анализ корреляции признаков

# %%
import seaborn as sns
# %matplotlib inline

# %%
df_train__num_features = df_train.select_dtypes(include='float64')

# %%
sns.pairplot(df_train__num_features)

# %% [markdown]
# **Бинарные признаки**

# %%
df_train['Ecology_2_A'].value_counts()
# Out:
# 0    9903
# 1      97
# Name: Ecology_2_A, dtype: int64

# %%
df_train['Ecology_3_A'].value_counts()
# Out:
# 0    9725
# 1     275
# Name: Ecology_3_A, dtype: int64

# %%
df_train['Shops_2_A'].value_counts()
# Out:
# 0    9175
# 1     825
# Name: Shops_2_A, dtype: int64

# %% [markdown]
# ### Матрица корреляций

# %%
plt.figure(figsize = (20,15))

sns.set(font_scale=1.4)
sns.heatmap(df_train.corr(), annot=True, linewidths=.5, cmap='GnBu')

plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# **Дальше я перешла в другой файл, стандартизировала данные с помощью standart scaler и уже стала тетсировать модели и пробовать разные сочетания призанков. Его отправлять нет смысла.По результатам выбран Лес. Его показатели я опишу в файле с готовой моделью и обарботанными данными**
